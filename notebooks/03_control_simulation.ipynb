# %% [markdown]
# # 03 - Control Policy Simulation
#
# This notebook simulates different HVAC control policies on historical data
# to estimate potential energy and cost savings.
#
# ## Goals
# 1. Define control policies (baseline, occupancy-aware, predictive)
# 2. Simulate each policy on historical data
# 3. Compare energy consumption and comfort metrics
# 4. Estimate cost savings with TOU pricing
# 5. Visualize policy performance

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Project imports
import sys
sys.path.append('..')
from src.control import compute_savings_and_setpoints, simulate_control_policy
from src.viz import plot_savings_summary

# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
# TODO: Load merged occupancy + HVAC data
# df = pd.read_csv('../data/processed/merged_data.csv', parse_dates=['timestamp'])

# %%
# TODO: Load TOU rates
# tou_df = pd.read_csv('../data/raw/tou/tou_rates.csv')

# %% [markdown]
# ## 2. Define Control Policies
#
# ### Baseline Policy
# Current operation: fixed schedules, no occupancy awareness.
#
# ### Occupancy-Aware Policy
# Setback when actual occupancy is zero (reactive).
#
# ### Predictive Policy
# Setback based on forecasted occupancy (proactive).

# %%
# TODO: Define comfort constraints
# comfort_constraints = {
#     'min_temp': 60,  # Heating setback limit
#     'max_temp': 85,  # Cooling setback limit
#     'pre_condition_time': 30,  # Minutes to pre-heat/cool
# }

# %% [markdown]
# ## 3. Simulate Policies

# %%
# TODO: Simulate occupancy-aware policy
# results_reactive, metrics_reactive = simulate_control_policy(
#     df, policy='occupancy_setback', policy_params=comfort_constraints
# )

# %%
# TODO: Simulate predictive policy
# results_predictive, metrics_predictive = simulate_control_policy(
#     df, policy='predictive_setback', policy_params=comfort_constraints
# )

# %% [markdown]
# ## 4. Compare Results

# %%
# TODO: Compare energy consumption across policies
# comparison = pd.DataFrame({
#     'Policy': ['Baseline', 'Reactive', 'Predictive'],
#     'Energy (kWh)': [baseline_energy, reactive_energy, predictive_energy],
#     'Cost ($)': [baseline_cost, reactive_cost, predictive_cost],
# })
# comparison

# %% [markdown]
# ## 5. Visualization

# %%
# TODO: Plot savings summary
# fig = plot_savings_summary(metrics_predictive)
# plt.show()

# %% [markdown]
# ## 6. Conclusions
#
# **Key Findings:**
# - TODO: Summarize savings potential
#
# **Recommendations:**
# - TODO: List recommendations for implementation
