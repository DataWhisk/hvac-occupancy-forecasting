# %% [markdown]
# # 02 - Forecasting Baselines
#
# This notebook develops and evaluates baseline models for occupancy forecasting.
#
# ## Goals
# 1. Prepare data for time-series forecasting
# 2. Train Prophet baseline model
# 3. Train transformer/LSTM baseline model
# 4. Evaluate and compare model performance
# 5. Visualize forecasts vs. actuals

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Project imports
import sys
sys.path.append('..')
from src.data import load_occupancy, engineer_features
from src.models import ProphetOccupancyModel, TransformerOccupancyModel

# %matplotlib inline

# %% [markdown]
# ## 1. Load and Prepare Data

# %%
# TODO: Load processed occupancy data
# df = pd.read_csv('../data/processed/features.csv', parse_dates=['timestamp'])

# %%
# TODO: Train/test split (e.g., last 2 weeks for testing)
# train_df = df[df['timestamp'] < '2024-01-01']
# test_df = df[df['timestamp'] >= '2024-01-01']

# %% [markdown]
# ## 2. Prophet Baseline

# %%
# TODO: Prepare data for Prophet (requires 'ds' and 'y' columns)
# prophet_df = train_df[['timestamp', 'occupancy_count']].rename(
#     columns={'timestamp': 'ds', 'occupancy_count': 'y'}
# )

# %%
# TODO: Train Prophet model
# model = ProphetOccupancyModel(zone_id='BH-101')
# model.fit(prophet_df)

# %%
# TODO: Generate forecasts
# forecast = model.predict(periods=96*14)  # 2 weeks at 15min intervals

# %% [markdown]
# ## 3. Transformer Baseline

# %%
# TODO: Train transformer model
# transformer = TransformerOccupancyModel(zone_id='BH-101')
# transformer.fit(train_df)

# %% [markdown]
# ## 4. Model Evaluation

# %%
# TODO: Compare model metrics
# prophet_metrics = model.evaluate(test_df)
# transformer_metrics = transformer.evaluate(test_df)
# print(f"Prophet: {prophet_metrics}")
# print(f"Transformer: {transformer_metrics}")

# %% [markdown]
# ## 5. Visualization

# %%
# TODO: Plot forecasts vs actuals
# fig, ax = plt.subplots(figsize=(14, 6))
# ax.plot(test_df['timestamp'], test_df['occupancy_count'], label='Actual')
# ax.plot(forecast['ds'], forecast['yhat'], label='Prophet')
# ax.legend()
# plt.show()
